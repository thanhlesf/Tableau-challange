# %%
# Dependencies
import pandas as pd
import glob

# %%
# Merging csv files (without repeating header)
citibike_files = glob.glob("*.csv") 
df = pd.concat((pd.read_csv(f, header = 0) for f in citibike_files))
df
# Out:
#        Unnamed: 0  tripduration                 starttime  \
# 0             0.0           226  2020-01-01 00:04:50.1920
# 1             1.0           377  2020-01-01 00:16:01.6700
# 2             2.0           288  2020-01-01 00:17:33.8770
# 3             3.0           435  2020-01-01 00:32:05.9020
# 4             4.0           231  2020-01-01 00:46:19.6780
# ...           ...           ...                       ...
# 36916         NaN          2828  2020-06-30 23:53:19.7380
# 36917         NaN          2729  2020-06-30 23:54:44.0100
# 36918         NaN          2788  2020-06-30 23:54:52.1920
# 36919         NaN          2702  2020-06-30 23:56:14.6650
# 36920         NaN          2649  2020-06-30 23:57:46.1490
#
#                        stoptime  start station id start station name  \
# 0      2020-01-01 00:08:37.0370              3186      Grove St PATH
# 1      2020-01-01 00:22:19.0800              3186      Grove St PATH
# ...

# %%
# Export file as a CSV
df.to_csv("2020-citibike-tripdata_JantoJun.csv")
